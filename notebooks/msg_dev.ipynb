# %%
from helpers.local_setup import _setup
_setup()

# %%
from utils.internal.msg.msg_downloader import MsgDownloader

# %%
config_path = '/Users/raf/Dev/code/msg2sar/data/configs/msg/seviri/2023/bogo_pl.json'
msg_d = MsgDownloader(config_path)
# Out:
# 2026-02-22 00:54:11 - INFO - MSG-CONFIG initialized with:
#  AOI-{'type': 'Feature', 'properties': {'id': 1, 'aoiName': 'bogo_pl'}, 'geometry': {'type': 'Polygon', 'coordinates': [[[20.57487885704091, 52.35089496859222], [21.907305229511838, 52.35089496859222], [21.907305229511838, 52.69753587307878], [20.57487885704091, 52.69753587307878], [20.57487885704091, 52.35089496859222]]]}}
# DOWNLOAD_DIR-/Users/raf/Dev/code/msg2sar/data/msg/seviri/2023/bogo_pl/download
# PROCESS_DIR-/Users/raf/Dev/code/msg2sar/data/msg/seviri/2023/bogo_pl/process
# DEM_PATH-/Users/raf/Dev/code/msg2sar/data/msg/seviri/2023/bogo_pl/download/bogo_pl_dem.nc

# %%
msg_d.download_prod()
# Out:
# 2026-02-22 00:54:13 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231216045743.467000000Z-NA
# 2026-02-22 00:54:18 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231216044243.436000000Z-NA
# 2026-02-22 00:54:29 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231204045742.016000000Z-NA
# 2026-02-22 00:54:39 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231204044242.039000000Z-NA
# 2026-02-22 00:54:44 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231122045742.734000000Z-NA
# 2026-02-22 00:54:49 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231122044242.768000000Z-NA
# 2026-02-22 00:54:54 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231110045742.558000000Z-NA
# 2026-02-22 00:54:59 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231110044242.613000000Z-NA
# 2026-02-22 00:55:04 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231017045742.616000000Z-NA
# 2026-02-22 00:55:10 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231017044242.697000000Z-NA
# 2026-02-22 00:55:15 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231005045742.283000000Z-NA
# 2026-02-22 00:55:20 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20231005044242.453000000Z-NA
# 2026-02-22 00:55:27 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230923045742.436000000Z-NA
# 2026-02-22 00:55:31 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230923044242.659000000Z-NA
# 2026-02-22 00:55:36 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230911045742.101000000Z-NA
# 2026-02-22 00:55:41 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230911044242.341000000Z-NA
# 2026-02-22 00:55:46 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230830045741.165000000Z-NA
# 2026-02-22 00:55:50 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230830044241.367000000Z-NA
# 2026-02-22 00:55:55 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230818045741.085000000Z-NA
# 2026-02-22 00:56:00 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230818044241.282000000Z-NA
# 2026-02-22 00:56:04 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230806045742.039000000Z-NA
# 2026-02-22 00:56:09 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230806044242.240000000Z-NA
# 2026-02-22 00:56:14 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230725045742.170000000Z-NA
# 2026-02-22 00:56:18 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230725044242.367000000Z-NA
# 2026-02-22 00:56:23 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230713045742.064000000Z-NA
# 2026-02-22 00:56:28 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230713044242.256000000Z-NA
# 2026-02-22 00:56:33 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230701045741.399000000Z-NA
# 2026-02-22 00:56:37 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230701044241.585000000Z-NA
# 2026-02-22 00:56:42 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230619045741.947000000Z-NA
# 2026-02-22 00:56:48 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230619044242.148000000Z-NA
# 2026-02-22 00:56:52 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230607045741.579000000Z-NA
# 2026-02-22 00:56:56 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230607044241.759000000Z-NA
# 2026-02-22 00:57:00 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230514045741.859000000Z-NA
# 2026-02-22 00:57:04 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230514044241.876000000Z-NA
# 2026-02-22 00:57:09 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230526045742.148000000Z-NA
# 2026-02-22 00:57:13 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230526044242.332000000Z-NA
# 2026-02-22 00:57:17 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230502045741.827000000Z-NA
# 2026-02-22 00:57:21 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230502044241.849000000Z-NA
# 2026-02-22 00:57:26 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230420045741.444000000Z-NA
# 2026-02-22 00:57:31 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230420044241.461000000Z-NA
# 2026-02-22 00:57:35 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230408045741.623000000Z-NA
# 2026-02-22 00:57:39 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230408044241.659000000Z-NA
# 2026-02-22 00:57:43 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230327045741.062000000Z-NA
# 2026-02-22 00:57:47 - INFO - Downloading MSG3-SEVI-MSG15-0100-NA-20230327044241.145000000Z-NA
# 2026-02-22 00:57:54 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230315045745.002000000Z-NA
# 2026-02-22 00:57:59 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230315044244.779000000Z-NA
# 2026-02-22 00:58:03 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230303045743.096000000Z-NA
# 2026-02-22 00:58:07 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230303044243.348000000Z-NA
# 2026-02-22 00:58:12 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230219045743.614000000Z-NA
# 2026-02-22 00:58:16 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230219044243.821000000Z-NA
# 2026-02-22 00:58:20 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230207045743.438000000Z-NA
# 2026-02-22 00:58:25 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230207044243.607000000Z-NA
# 2026-02-22 00:58:30 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230126045742.538000000Z-NA
# 2026-02-22 00:58:34 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230126044242.711000000Z-NA
# 2026-02-22 00:58:38 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230114045743.440000000Z-NA
# 2026-02-22 00:58:44 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230114044243.541000000Z-NA
# 2026-02-22 00:58:48 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230102045743.137000000Z-NA
# 2026-02-22 00:58:53 - INFO - Downloading MSG4-SEVI-MSG15-0100-NA-20230102044243.246000000Z-NA

# %%
from helpers.local_setup import _setup
_setup()
import os
from utils.internal.io.json_io import open_json
from settings.paths import KEYS_DIR
from eumdac.token import AccessToken
from eumdac.datastore import DataStore
from utils.internal.io.json_io import geojson_to_wkt
from utils.internal.geo.poly import geojson_to_bbox

from eumdac.cli import search

# %%
from datetime import datetime

# %%
geojson_path = '/Users/raf/Dev/code/msg2sar/data/polygons/bogo_pl.geojson'

# %%
geojson = open_json(geojson_path)
bbox = geojson_to_bbox(geojson)

# %%
bbox
# Out:
# [20.633936889906916, 52.38682741559186, 21.848247196645833, 52.66160342607914]

# %%
start_str = "20241216_044449"
end_str = "20241216_054449"
fmt = "%Y%m%d_%H%M%S"
start = datetime.strptime(start_str, fmt)
end = datetime.strptime(end_str, fmt)

# %%
fci_c = datastore.opensearch("pi=EO:EUM:DAT:0665")

# %%
fci_c
# Out:
# <class 'eumdac.collection.SearchResults'>(EO:EUM:DAT:0665, {'dtend': None, 'geo': None, 'title': None, 'dtstart': None, 'bbox': None, 'coverage': None, 'sort': None, 'set': None, 'centerOfLongitude': None, 'type': None, 'sat': None, 'repeatCycleIdentifier': None, 'publication': None})

# %%
fci = datastore.get_collection("EO:EUM:DAT:0665")

# %%
fci
# Out:
# <class 'eumdac.collection.Collection'>(EO:EUM:DAT:0665)

# %%
prod = fci.search(dtstart=start, dtend=end)

# %%
for p in prod:
    print(p)
# Out:
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216054254_IDPFI_OPE_20241216054007_20241216054924_N__O_0035_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216053254_IDPFI_OPE_20241216053007_20241216053924_N__O_0034_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216052252_IDPFI_OPE_20241216052007_20241216052924_N__O_0033_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216051254_IDPFI_OPE_20241216051007_20241216051924_N__O_0032_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216050252_IDPFI_OPE_20241216050007_20241216050924_N__O_0031_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216045250_IDPFI_OPE_20241216045007_20241216045928_N__O_0030_0000
# W_XX-EUMETSAT-Darmstadt,IMG+SAT,MTI1+FCI-1C-RRAD-HRFI-FD--x-x---x_C_EUMT_20241216044254_IDPFI_OPE_20241216044007_20241216044928_N__O_0029_0000

# %%
import shutil
f_dir = "./test2"
for product in prod:
    with product.open() as f_src, open(os.path.join(f_dir, f_src.name), mode='wb') as f_dst:
        shutil.copyfileobj(f_src, f_dst)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[41], line 5
#       3 for product in prod:
#       4     with product.open() as f_src, open(os.path.join(f_dir, f_src.name), mode='wb') as f_dst:
# ----> 5         shutil.copyfileobj(f_src, f_dst)
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/shutil.py:203, in copyfileobj(fsrc, fdst, length)
#     201 fsrc_read = fsrc.read
#     202 fdst_write = fdst.write
# --> 203 while buf := fsrc_read(length):
#     204     fdst_write(buf)
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)   1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/envs/msg2sar/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
def __eumetsat_init():
    secrets = open_json(os.path.join(KEYS_DIR, 'keys.json'))
    key = secrets['eumetsat']['consumer_key']
    secret = secrets['eumetsat']['consumer_secret']
    token = AccessToken((key, secret))
    return DataStore(token)


wkt = geojson_to_wkt(geojson_path)

collections = [
    'EO:EUM:DAT:MSG:HRSEVIRI'
]

# %%
datastore = __eumetsat_init()
for collection in datastore.collections:
    print(f"{collection} - {collection.title}")
# Out:
# EO:EUM:DAT:0959 - IASI Carbon Monoxide Profiles FORLI-CO Climate Data Record Release 1 - Metop-A and -B
# EO:EUM:DAT:0960 - IASI SO2 Climate Data Record Release 1 - Metop-A and -B
# EO:EUM:DAT:0962 - SEVIRI Rapid Scan High Rate Level 1.5 Image Data Climate Data Record Release 1 - MSG
# EO:EUM:DAT:0961 - HIRS Level 1C Fundamental Data Record Release 2 - Multimission - Global
# EO:EUM:DAT:0964 - SSM/T Level 1C Fundamental Data Record Release 1 - Multimission - Global
# EO:EUM:DAT:0963 - SI-1 Fundamental Data Record Release 1 - Meteor - Polar
# EO:EUM:DAT:0986 - Deep Convective Cloud System Monitoring Database - TOOCAN v2.08 Africa
# EO:EUM:DAT:0987 - Deep Convective Cloud System Monitoring Database - CACATOES v1.04 Africa
# EO:EUM:DAT:0910 - CM SAF Passive Microwave Upper Tropospheric Humidity (UTH) Data Record - Edition 2
# EO:EUM:DAT:0908 - Auxiliary data TLE – AWS PFM
# EO:EUM:DAT:METOP:AVHRRL1 - AVHRR Level 1B - Metop - Global
# EO:EUM:DAT:0921 - GIRAFE v1: CM SAF Global Interpolated RAinFall Estimation version 1
# EO:EUM:DAT:METOP:SOMO25 - ASCAT Soil Moisture at 25 km Swath Grid in NRT - Metop
# EO:EUM:DAT:METOP:SOMO12 - ASCAT Soil Moisture at 12.5 km Swath Grid in NRT - Metop
# EO:EUM:DAT:0557 - OLCI Level 2 Ocean Colour Reduced Resolution (version BC003) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0799 - All Sky Radiance (BUFR) - MTG - 0 degree
# EO:EUM:DAT:0556 - OLCI Level 2 Ocean Colour Full Resolution (version BC003) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0558 - AVHRR GAC Atmospheric Motion Vectors Climate Data Record Release 2 - Multimission - Polar
# EO:EUM:DAT:0576 - IASI All Sky Temperature and Humidity Profiles - Climate Data Record Release 1.1 - Metop-A and -B
# EO:EUM:DAT:0579 - Polar Multi-Sensor Aerosol Optical Properties Climate Data Record Release 1 - Metop-A and -B
# EO:EUM:DAT:0584 - SRAL Level 1B (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0583 - SRAL Level 1A Unpacked L0 Complex Echoes (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0586 - SRAL Level 2 Altimetry Global (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0344 - MHS Microwave Humidity Sounder Climate Data Record Release 2 - Metop-A and -B
# EO:EUM:DAT:0585 - SRAL Level 1B Stack Echoes (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0343 - SSM/T-2 Microwave Humidity Sounder Climate Data Record Release 2 - DMSP
# EO:EUM:DAT:0345 - ATMS Level 1C Climate Data Record Release 1 - NPP
# EO:EUM:DAT:0103 - TROPOMI Level 2 Aerosol Layer Height Products in NRT - Sentinel-5P
# EO:EUM:DAT:0348 - MWHS-1 Level 1C Climate Data Record Release 1
# EO:EUM:DAT:0349 - MWHS-2 Level 1C Climate Data Record Release 1
# EO:EUM:DAT:0582 - SLSTR Level 2 Sea Surface Temperature (SST) (version BC003) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:METOP:ASCSZR1B - ASCAT Level 1 Sigma0 resampled at 12.5 km Swath Grid - Metop - Global
# EO:EUM:DAT:0581 - SLSTR Level 1B Radiances and Brightness Temperatures (version BC003) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0998 - Atmospheric Motion Vectors (BUFR) - MTG - 0 degree
# EO:EUM:DAT:0758 - IASI Principal Components Scores Fundamental Data Record Release 1 - Metop-A and -B
# EO:EUM:DAT:METOP:OAS025 - ASCAT Winds and Soil Moisture at 25 km Swath Grid - Metop
# EO:EUM:DAT:METOP:AMSUL1 - AMSU-A Level 1B - Metop - Global
# EO:EUM:DAT:0533 - GOME-2 Level 1B Fundamental Data Record Release 3 - Metop-A and -B
# EO:EUM:DAT:MSG:CLM - Cloud Mask - MSG - 0 degree
# EO:EUM:DAT:DMSP:OSI-401-B - Global Sea Ice Concentration (netCDF) - DMSP
# EO:EUM:DAT:METOP:LSA-002 - EPS Daily Land Surface Temperature - Metop
# EO:EUM:DAT:0782 - LI Lightning Groups - MTG - 0 degree
# EO:EUM:DAT:0300 - GSA Level 2 Climate Data Record Release 2 - MFG and MSG - 0 degree
# EO:EUM:DAT:0302 - GSA Level 2 Climate Data Record Release 2 - MFG - 63 degree
# EO:EUM:DAT:0301 - GSA Level 2 Climate Data Record Release 2 - MFG - 57 degree
# EO:EUM:DAT:0303 - AMSU-B Microwave Humidity Sounder Climate Data Record Release 1 - NOAA
# EO:EUM:DAT:0305 - MHS Microwave Humidity Sounder Climate Data Record Release 1 - Metop and NOAA
# EO:EUM:DAT:0274 - RINEX Auxiliary Data - Sentinel-6
# EO:EUM:DAT:0069 - TROPOMI Level 1B Consolidated Earth Radiances Measurements - Sentinel-5P
# EO:EUM:DAT:METOP:ASCSZF1B - ASCAT Level 1 Sigma0 Full Resolution - Metop - Global
# EO:EUM:DAT:METOP:GOMEL1 - GOME-2 Level 1B - Metop - Global
# EO:EUM:DAT:1101 - TROPOMI Methane (CH4) - Sentinel-5P
# EO:EUM:DAT:METOP:IASIL1C-ALL - IASI Level 1C - All Spectral Samples - Metop - Global
# EO:EUM:DAT:MSG:RSS-CLM - Rapid Scan Cloud Mask - MSG
# EO:EUM:CM:METOP:ASCSZFR02 - ASCAT Level 1 SZF Climate Data Record Release 2 - Metop
# EO:EUM:DAT:0905 - MWR Level 1B – Arctic Weather Satellite Proto-Flight Model - Global
# EO:EUM:DAT:METOP:GLB-SST-NC - Global L3C AVHRR Sea Surface Temperature (GHRSST) - Metop
# EO:EUM:DAT:0078 - TROPOMI Level 2 Sulphur Dioxide (SO2) Total Column Products in NRT - Sentinel-5P
# EO:EUM:DAT:0077 - TROPOMI Level 2 Ozone (O3) Total Column Products in NRT - Sentinel-5P
# EO:EUM:DAT:0070 - TROPOMI Level 1B Solar Irradiance Measurements - SWIR Module - Sentinel-5P
# EO:EUM:DAT:0072 - TROPOMI Level 2 Aerosol Index Products in NRT - Sentinel-5P
# EO:EUM:DAT:0071 - TROPOMI Level 1B Solar Irradiance Measurements - UVN Module - Sentinel-5P
# EO:EUM:DAT:0074 - TROPOMI Level 2 Cloud Fraction, Albedo, Top Pressure Products in NRT - Sentinel-5P
# EO:EUM:DAT:0073 - TROPOMI Level 2 Carbon Monoxide (CO) Total Column Products in NRT - Sentinel-5P
# EO:EUM:DAT:0076 - TROPOMI Level 2 Nitrogen Dioxide (NO2), Total And Tropospheric Columns Products in NRT - Sentinel-5P
# EO:EUM:DAT:0075 - TROPOMI Level 2 Formaldehyde (HCHO) Total Column Products in NRT - Sentinel-5P
# EO:EUM:DAT:0088 - Land Surface Temperature Data Record - MSG
# EO:EUM:DAT:METOP:NTO - Near Real-Time Total Column - Metop
# EO:EUM:DAT:0834 - SRAL Level 2 Altimetry Global (version BC005) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0833 - SRAL Level 1B (version BC005) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0836 - SRAL Level 1A Unpacked L0 Complex Echoes (version BC005) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0835 - SRAL Level 1B Stack Echoes (version BC005) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0838 - Poseidon-4 Altimetry Level 1A High Resolution (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0837 - Climate-quality Advanced Microwave Radiometer Level 2 Products (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0839 - Poseidon-4 Altimetry Level 1B High Resolution (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0841 - Poseidon-4 Altimetry Level 2 High Resolution (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0840 - Poseidon-4 Altimetry Level 1B Low Resolution (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0601 - Poseidon-4 Level 3 Altimetry Low Resolution in NTC - Sentinel-6
# EO:EUM:DAT:0842 - Poseidon-4 Altimetry Level 2 Low Resolution (baseline version F08) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:0602 - TROPOMI Level 2 Ozone (O3) Profile in NRT - Sentinel-5P
# EO:EUM:DAT:METOP:ASCSZO1B - ASCAT Level 1 Sigma0 resampled at 25 km Swath Grid - Metop - Global
# EO:EUM:DAT:0850 - Poseidon-4 Altimetry Level 1A High Resolution - Sentinel-6
# EO:EUM:DAT:0852 - Poseidon-4 Altimetry Level 1B Low Resolution - Sentinel-6
# EO:EUM:DAT:0851 - Poseidon-4 Altimetry Level 1B High Resolution - Sentinel-6
# EO:EUM:DAT:0854 - Poseidon-4 Altimetry Level 2 Low Resolution - Sentinel-6
# EO:EUM:DAT:0853 - Radio Occultation Level 1B Products - Sentinel-6
# EO:EUM:DAT:0856 - Advanced Microwave Radiometer for Climate Level 2 data - Sentinel-6
# EO:EUM:DAT:0855 - Poseidon-4 Altimetry Level 2 High Resolution - Sentinel-6
# EO:EUM:DAT:0858 - Poseidon-4 Level 2P Altimetry High Resolution - Sentinel-6
# EO:EUM:DAT:0615 - SLSTR Level 1B Radiances and Brightness Temperatures (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0857 - Poseidon-4 Level 2P Altimetry Low Resolution - Sentinel-6
# EO:EUM:DAT:0859 - Poseidon-4 Level 3 Altimetry High Resolution - Sentinel-6
# EO:EUM:DAT:0617 - Optimal Cloud Analysis Climate Data Record Release 1 - MSG - 0 degree
# EO:EUM:DAT:MSG:HRSEVIRI-IODC - High Rate SEVIRI Level 1.5 Image Data - MSG - Indian Ocean
# EO:EUM:DAT:0863 - Surface Radiation Data Set - Heliosat (SARAH) - Edition 3
# EO:EUM:DAT:0862 - AVHRR Fundamental Data Record - Release 1 - Multimission
# EO:EUM:CM:METOP:ASCSZOR02 - ASCAT Level 1 SZO Climate Data Record Release 2 - Metop
# EO:EUM:DAT:0801 - Active Fire Monitoring (CAP) - MTG - 0 degree
# EO:EUM:DAT:0800 - Cloud Mask (GRIB2) - MTG - 0 degree
# EO:EUM:DAT:METOP:IASPCS01 - IASI Level 1 Principal Component Scores - Metop - Global
# EO:EUM:DAT:METOP:OSI-104 - ASCAT Coastal Winds at 12.5 km Swath Grid - Metop
# EO:EUM:DAT:METOP:IASIL2COX - IASI Carbon Monoxide Profiles FORLI-CO - Metop
# EO:EUM:DAT:0676 - Atmospheric Motion Vectors (netCDF) - MTG - 0 degree
# EO:EUM:DAT:0678 - Cloud Mask (netCDF) - MTG - 0 degree
# EO:EUM:DAT:0677 - All Sky Radiance (netCDF) - MTG - 0 degree
# EO:EUM:DAT:0679 - Clear Sky Reflectance Map - MTG - 0 degree
# EO:EUM:DAT:0683 - Global Instability Indices - MTG - 0 degree
# EO:EUM:DAT:METOP:MHSL1 - MHS Level 1B - Metop - Global
# EO:EUM:DAT:0682 - Active Fire Monitoring (netCDF) - MTG - 0 degree
# EO:EUM:DAT:0685 - Outgoing LW radiation at TOA - MTG - 0 degree
# EO:EUM:DAT:0684 - Optimal Cloud Analysis - MTG - 0 degree
# EO:EUM:DAT:0687 - LI Accumulated Flash Area - MTG - 0 degree
# EO:EUM:DAT:0686 - LI Accumulated Flashes - MTG - 0 degree
# EO:EUM:DAT:0688 - LI Accumulated Flash Radiance - MTG - 0 degree
# EO:EUM:DAT:0681 - Cloud Top Temperature and Height - MTG - 0 degree
# EO:EUM:DAT:0680 - Cloud Type - MTG - 0 degree
# EO:EUM:DAT:0694 - FCI Level 3 Sea Surface Temperature - MTG
# EO:EUM:DAT:0690 - LI Lightning Events Filtered - MTG - 0 degree
# EO:EUM:DAT:0691 - LI Lightning Flashes - MTG - 0 degree
# EO:EUM:DAT:MSG:MSG15-RSS - Rapid Scan High Rate SEVIRI Level 1.5 Image Data - MSG
# EO:EUM:DAT:0874 - CLARA-A3: CM SAF cLoud, Albedo and surface RAdiation dataset from AVHRR data - Edition 3
# EO:EUM:DAT:0881 - MVIRI Level 1.5 Climate Data Record Release 2 - MFG - 57 degree
# EO:EUM:DAT:0880 - MVIRI Level 1.5 Climate Data Record Release 2 - MFG - 0 degree
# EO:EUM:DAT:0882 - MVIRI Level 1.5 Climate Data Record Release 2 - MFG - 63 degree
# EO:EUM:DAT:0885 - OLCI Level 1B Full Resolution (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0645 - Global Sea Ice Concentration Interim Climate Data Record Release 3 - DMSP
# EO:EUM:DAT:0886 - OLCI Level 1B Reduced Resolution (version BC004) - Sentinel-3 - Reprocessed
# EO:EUM:DAT:0405 - Atmospheric Motion Vectors Climate Data Record Release 2 - MFG and MSG - 0 degree
# EO:EUM:DAT:0407 - OLCI Level 2 Ocean Colour Full Resolution - Sentinel-3
# EO:EUM:DAT:0406 - SRAL Level 1B - Sentinel-3
# EO:EUM:DAT:0409 - OLCI Level 1B Full Resolution - Sentinel-3
# EO:EUM:DAT:0408 - OLCI Level 2 Ocean Colour Reduced Resolution - Sentinel-3
# EO:EUM:DAT:METOP:IASSND02 - IASI Combined Sounding Products - Metop
# EO:EUM:DAT:0410 - OLCI Level 1B Reduced Resolution - Sentinel-3
# EO:EUM:DAT:0894 - Atmospheric Motion Vectors Climate Data Record Release 1 - MFG - Indian Ocean 57 degrees E
# EO:EUM:DAT:0412 - SLSTR Level 2 Sea Surface Temperature (SST) - Sentinel-3
# EO:EUM:DAT:0411 - SLSTR Level 1B Radiances and Brightness Temperatures - Sentinel-3
# EO:EUM:DAT:0895 - Atmospheric Motion Vectors Climate Data Record Release 1 - MFG - Indian Ocean 63 degrees E
# EO:EUM:DAT:0414 - SRAL Level 1B stack echoes - Sentinel-3
# EO:EUM:DAT:0413 - SRAL Level 1A Unpacked L0 Complex echos - Sentinel-3
# EO:EUM:DAT:0416 - SLSTR Level 2 Aerosol Optical Depth - Sentinel-3
# EO:EUM:DAT:0415 - SRAL Level 2 Altimetry Global - Sentinel-3
# EO:EUM:DAT:0417 - SLSTR Level 2 Fire Radiative Power - Sentinel-3
# EO:EUM:DAT:MSG:HRSEVIRI - High Rate SEVIRI Level 1.5 Image Data - MSG - 0 degree
# EO:EUM:DAT:0662 - FCI Level 1c Normal Resolution Image Data - MTG - 0 degree
# EO:EUM:DAT:0665 - FCI Level 1c High Resolution Image Data - MTG - 0 degree
# EO:EUM:DAT:MSG:CLM-IODC - Cloud Mask - MSG - Indian Ocean
# EO:EUM:DAT:1003 - SLSTR Level 2 Atmospheric Motion Vectors - Sentinel-3
# EO:EUM:DAT:0398 - Fire Risk Map - Released Energy Based - MSG
# EO:EUM:DAT:0151 - AVHRR Global (dual) Atmospheric Motion Vectors Climate Data Record Release 1 - Metop-A/B and -B/A
# EO:EUM:DAT:0394 - Land Surface Temperature with Directional Effects - MSG
# EO:EUM:DAT:0152 - AVHRR Polar Atmospheric Motion Vectors Climate Data Record Release 2 - Metop-A and -B
# EO:EUM:DAT:1015 - Poseidon-4 Level 3 Altimetry Low Resolution (baseline DT2024) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:1027 - IASI Ozone (O3) Climate Data Record (CDR) Release 1 - Metop-A and -B
# EO:EUM:DAT:0590 - IASI Level 1C Climate Data Record Release 2 - Metop-A and -B
# EO:EUM:DAT:0374 - Commercial Radio Occultation Level 1B data - Multimission
# EO:EUM:DAT:MSG:CTH - Cloud Top Height - MSG - 0 degree
# EO:EUM:DAT:METOP:OSI-150-A - ASCAT L2 25 km Winds Data Record Release 1 - Metop
# EO:EUM:DAT:0143 - Poseidon-4 Level 3 Wind/Wave Products Low Resolution in NRT - Sentinel-6
# EO:EUM:DAT:METOP:OSI-150-B - ASCAT L2 12.5 km Winds Data Record Release 1 - Metop
# EO:EUM:DAT:0142 - Poseidon-4 Level 2P Wind/Wave Products Low Resolution in NRT - Sentinel-6
# EO:EUM:DAT:1083 - SEVIRI Rapid Scan Atmospheric Motion Vectors Climate Data Record Release 1 - MSG
# EO:EUM:DAT:1086 - Precipitation rate at ground by blended FCI IR / LEO MW precipitation - MTG - 0 Degree
# EO:EUM:DAT:1088 - Land Surface Temperature - MTG
# EO:EUM:DAT:1087 - Accumulated precipitation at ground by blended MW+IR and FCI - MTG - 0 Degree
# EO:EUM:DAT:1091 - FCI Snow detection (snow mask) by VIS/NIR radiometry - MTG
# EO:EUM:DAT:MSG:CTH-IODC - Cloud Top Height - MSG - Indian Ocean
# EO:EUM:DAT:MULT:HIRSL1 - HIRS Level 1B - Metop - Global
# EO:EUM:DAT:1069 - Poseidon-4 Altimetry Level 1A High Resolution (baseline version G01) - Sentinel-6 - Reprocessed
# EO:EUM:CM:METOP:ASCSZRR02 - ASCAT Level 1 SZR Climate Data Record Release 2 - Metop
# EO:EUM:DAT:1071 - Poseidon-4 Altimetry Level 1B Low Resolution (baseline version G01) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:1070 - Poseidon-4 Altimetry Level 1B High Resolution (baseline version G01) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:1073 - Advanced Microwave Radiometer (AMR-C) Level 2 Products (baseline version G01) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:1072 - Poseidon-4 Altimetry Level 2 High Resolution (baseline version G01) - Sentinel-6 - Reprocessed
# EO:EUM:DAT:1074 - Poseidon-4 Altimetry Level 2 Low Resolution (baseline version G01) - Sentinel-6 - Reprocessed

# %%
#!/usr/bin/env python3
"""
EUMETSAT IRS + SEVIRI downloader using EUMDAC.
pip install eumdac shapely geojson
"""

import os
import json
from eumdac import DataStore, ClientCredentials
from utils.internal.io.json_io import geojson_to_wkt


def download_eumetsat_polygon(
        user,
        password,
        geojson_path,
        start_time,
        end_time,
        output_dir="./downloads",
        collections=None
    ):
    """
    Download MTG-IRS and MSG-SEVIRI data over polygon.
    
    user/password: EOP credentials
    geojson_path: e.g. {'type': 'FeatureCollection', 'features': [{'geometry': {'type': 'Polygon', ...}}]}
    start_time/end_time: 'YYYY-MM-DDTHH:MM:SSZ' UTC
    collections: list or None (auto: IRS L1/L2, SEVIRI L1.5)
    """
    os.makedirs(output_dir, exist_ok=True)
    
    # Authenticate
    credentials = ClientCredentials(user, password)
    datastore = DataStore(credentials)
    
    # Polygon WKT
    wkt = geojson_to_wkt(geojson_path)
    
    # Auto-collections if None (MTG-IRS + MSG-SEVIRI)
    if collections is None:
        collections = [
            # MTG-IRS Level 1 radiance (your guide)
            "EO:EUM:DAT:MSG:IRS_L1",
            # MTG-IRS Level 2 profiles (T, q_v)
            "EO:EUM:DAT:MSG:IRS_L2",
            # MSG-SEVIRI L1.5 HRIT/NetCDF
            "EO:EUM:DAT:MSG:HRSEVIRI",
            # MSG-SEVIRI L2 WV/TPW
            "EO:EUM:DAT:MSG:WV_002_013"  # Adjust per exact product
        ]
    
    products = []
    for collection in collections:
        print(f"Searching {collection}...")
        
        # OpenSearch query by polygon + time
        search = datastore.get_search(
            collection=collection,
            start_time=start_time,
            completion_time=end_time,
            spatial_shape=wkt
        )
        
        # Fetch results (paginated)
        hits = list(search.get())
        print(f"Found {len(hits)} products for {collection}")
        products.extend(hits)
    
    if not products:
        print("No products found.")
        return
    
    # Download all (parallel optional)
    print(f"Downloading {len(products)} products...")
    for product in products:
        product_id = product['id']
        filename = f"{product_id}.zip"  # Or .nc
        download_path = os.path.join(output_dir, filename)
        
        if os.path.exists(download_path):
            print(f"Skipping {filename}")
            continue
            
        print(f"Downloading {product_id}...")
        datastore.download(product_id, download_path)
    
    print("Download complete!")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 9
#       7 import os
#       8 import json
# ----> 9 from eumdac import DataStore, ClientCredentials
#      10 from utils.internal.io.json_io import geojson_to_wkt
#      13 def download_eumetsat_polygon(
#      14         user,
#      15         password,
#    (...)     20         collections=None
#      21     ):
#
# ImportError: cannot import name 'ClientCredentials' from 'eumdac' (/opt/anaconda3/envs/msg2sar/lib/python3.12/site-packages/eumdac/__init__.py)

# %%
# ---------------------------------------------------------------------
# Usage example
# ---------------------------------------------------------------------
if __name__ == "__main__":
    USER = "your_eop_username"
    PASSWORD = "your_eop_password"
    
    # Example Warsaw polygon GeoJSON (save as warsaw_polygon.geojson)
    geojson_ex = {
        "type": "FeatureCollection",
        "features": [{
            "type": "Feature",
            "geometry": {
                "type": "Polygon",
                "coordinates": [[
                    [20.9, 52.1], [21.1, 52.1], [21.1, 52.3],
                    [20.9, 52.3], [20.9, 52.1]
                ]]
            }
        }]
    }
    with open("warsaw_polygon.geojson", "w") as f:
        json.dump(geojson_ex, f)
    
    # Time window (UTC)
    start = "2026-02-17T00:00:00Z"
    end = "2026-02-20T23:59:59Z"
    
    download_eumetsat_polygon(
        USER, PASSWORD,
        "warsaw_polygon.geojson",
        start, end,
        output_dir="./eumetsat_data"
    )
